# %%
import os
import numpy as np
import pandas as pd
import sklearn

# %%
s1 = pd.Series([1, 2, 3, 4, 5])

# %%
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s2 = pd.Series([1, 2, 3, 4, 5], ['a', 'b', 'c', 'd', 'e'])

# %%
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
d = {'a' : 1, 'b' : 2, 'c' : 3, 'd': 4}
s3 = pd.Series(d)

# %%
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s3['d']
# Out:
# 4

# %%
s3[s3 <= 3]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s3 + s2
# Out:
# a    2.0
# b    4.0
# c    6.0
# d    8.0
# e    NaN
# dtype: float64

# %% [markdown]
# # LGBR Survey

# %%
daily_df = pd.read_csv('./european-union-lgbt-survey-2012/LGBT_Survey_DailyLife.csv')

# %%
daily_df
# Out:
#           CountryCode          subset  question_code  \
# 0             Austria         Lesbian           b1_a
# 1             Austria         Lesbian           b1_a
# 2             Austria         Lesbian           b1_a
# 3             Austria         Lesbian           b1_a
# 4             Austria         Lesbian           b1_a
# 5             Austria             Gay           b1_a
# 6             Austria             Gay           b1_a
# 7             Austria             Gay           b1_a
# 8             Austria             Gay           b1_a
# 9             Austria             Gay           b1_a
# 10            Austria  Bisexual women           b1_a
# 11            Austria  Bisexual women           b1_a
# 12            Austria  Bisexual women           b1_a
# 13            Austria  Bisexual women           b1_a
# 14            Austria  Bisexual women           b1_a
# 15            Austria    Bisexual men           b1_a
# 16            Austria    Bisexual men           b1_a
# ...

# %%
daily_df = daily_df.dropna()

# %%
daily_df
# Out:
#       CountryCode          subset  question_code  \
# 4         Austria         Lesbian           b1_a
# 10        Austria  Bisexual women           b1_a
# 13        Austria  Bisexual women           b1_a
# 14        Austria  Bisexual women           b1_a
# 15        Austria    Bisexual men           b1_a
# 19        Austria    Bisexual men           b1_a
# 20        Austria     Transgender           b1_a
# 24        Austria     Transgender           b1_a
# 25        Belgium         Lesbian           b1_a
# 35        Belgium  Bisexual women           b1_a
# 36        Belgium  Bisexual women           b1_a
# 39        Belgium  Bisexual women           b1_a
# 40        Belgium    Bisexual men           b1_a
# 41        Belgium    Bisexual men           b1_a
# 44        Belgium    Bisexual men           b1_a
# 45        Belgium     Transgender           b1_a
# 49        Belgium     Transgender           b1_a
# 53       Bulgaria         Lesbian           b1_a
# ...

# %%
daily_df[daily_df['subset'] == 'Lesbian']
# Out:
#           CountryCode   subset  question_code  \
# 4             Austria  Lesbian           b1_a
# 25            Belgium  Lesbian           b1_a
# 53           Bulgaria  Lesbian           b1_a
# 54           Bulgaria  Lesbian           b1_a
# 75             Cyprus  Lesbian           b1_a
# 76             Cyprus  Lesbian           b1_a
# 77             Cyprus  Lesbian           b1_a
# 78             Cyprus  Lesbian           b1_a
# 79             Cyprus  Lesbian           b1_a
# 104    Czech Republic  Lesbian           b1_a
# 150           Denmark  Lesbian           b1_a
# 154           Denmark  Lesbian           b1_a
# 175           Estonia  Lesbian           b1_a
# 178           Estonia  Lesbian           b1_a
# 179           Estonia  Lesbian           b1_a
# 203            Greece  Lesbian           b1_a
# 204            Greece  Lesbian           b1_a
# 303           Croatia  Lesbian           b1_a
# 304           Croatia  Lesbian           b1_a
# ...

# %%
discr_df = pd.read_csv('./european-union-lgbt-survey-2012/LGBT_Survey_Discrimination.csv')

# %%
discr_df
# Out:
#           CountryCode          subset question_code  \
# 0             Austria         Lesbian           c10
# 1             Austria         Lesbian           c10
# 2             Austria         Lesbian           c10
# 3             Austria         Lesbian           c10
# 4             Austria         Lesbian           c10
# 5             Austria         Lesbian           c10
# 6             Austria         Lesbian           c10
# 7             Austria         Lesbian           c10
# 8             Austria         Lesbian           c10
# 9             Austria             Gay           c10
# 10            Austria             Gay           c10
# 11            Austria             Gay           c10
# 12            Austria             Gay           c10
# 13            Austria             Gay           c10
# 14            Austria             Gay           c10
# 15            Austria             Gay           c10
# 16            Austria             Gay           c10
# ...

# %%
discr_df.head()
# Out:
#   CountryCode   subset question_code  \
# 0     Austria  Lesbian           c10
# 1     Austria  Lesbian           c10
# 2     Austria  Lesbian           c10
# 3     Austria  Lesbian           c10
# 4     Austria  Lesbian           c10
#
#                                       question_label  \
# 0  Have you ever experienced any of the following...
# 1  Have you ever experienced any of the following...
# 2  Have you ever experienced any of the following...
# 3  Have you ever experienced any of the following...
# 4  Have you ever experienced any of the following...
#
#                                               answer percentage notes
# 0         Difficulty in gaining access to healthcare          2   [0]
# 1  Having to change general practitioners or othe...          8   NaN
# 2  Receiving unequal treatment when dealing with ...          3   [0]
# 3  Foregoing treatment for fear of discrimination...          5   NaN
# ...

# %%
discr_df = discr_df.dropna()

# %%
discr_df
# Out:
#       CountryCode          subset question_code  \
# 0         Austria         Lesbian           c10
# 2         Austria         Lesbian           c10
# 6         Austria         Lesbian           c10
# 7         Austria         Lesbian           c10
# 18        Austria  Bisexual women           c10
# 19        Austria  Bisexual women           c10
# 20        Austria  Bisexual women           c10
# 21        Austria  Bisexual women           c10
# 22        Austria  Bisexual women           c10
# 23        Austria  Bisexual women           c10
# 24        Austria  Bisexual women           c10
# 25        Austria  Bisexual women           c10
# 27        Austria    Bisexual men           c10
# 28        Austria    Bisexual men           c10
# 29        Austria    Bisexual men           c10
# 30        Austria    Bisexual men           c10
# 31        Austria    Bisexual men           c10
# 32        Austria    Bisexual men           c10
# ...

# %%
discr_df.isnull().sum()
# Out:
# CountryCode       0
# subset            0
# question_code     0
# question_label    0
# answer            0
# percentage        0
# notes             0
# dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
clf = DecisionTreeClassifier()
le = preprocessing.LabelEncoder()

# %%
X = [discr_df['CountryCode'].to_numpy(), discr_df['subset'].to_numpy()]
Y = discr_df['percentage'].to_numpy()

# %%
X = X.T
X
# Out:
# array([['Austria', 'Lesbian'],
#        ['Austria', 'Lesbian'],
#        ['Austria', 'Lesbian'],
#        ...,
#        ['Slovenia', 'Bisexual men'],
#        ['Slovenia', 'Transgender'],
#        ['Slovenia', 'Transgender']], dtype=object)

# %%
X.shape
# Out:
# (6980, 2)

# %%
Y.shape
# Out:
# (6980,)

# %%
X = np.array(X)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
clf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-5c93c534242c> in <module>
# ----> 1 clf.fit(x_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     128         random_state = check_random_state(self.random_state)
#     129         if check_input:
# --> 130             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     131             y = check_array(y, ensure_2d=False, dtype=None)
#     132             if issparse(X):
#
# ...
