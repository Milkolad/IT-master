# %% [markdown]
# # Самолеты
#
# * Построить список уникальных типов самолетов, зарегистрированных в России
# * Какой тип самолета имеет самую раннюю дату выдчи сертификата
# * Построить запрос: Владелец Аэропорта, Аэропорт, Пассажиропоток суммарный за 2018, грузопоток суммарный за 2018
# * Перечислить аэропорты, где пассажиропоток меньше медианы, а грузопоток больше медианы
# * Перечислить авиакомпании у которых нет типов воздушных судов зарегистрированных в России
# * Выведите список: Месяц, суммарный пассажиропоток за данный месяц, аэропорт, в котором пассажиропоток в данном месяце максимальный
# * Вывести список: тип аэропорта, средний грузопоток в месяц в аэропортах данного типа

# %%
import numpy as np
import pandas as pd

# %%
aircraft_df = pd.read_csv('./aircraft.csv', encoding='utf-8', sep=';', parse_dates=['дата действующего свидетельства о регистрации'])

# %%
airlines_df = pd.read_csv('./airlines.csv', encoding='utf-8')

# %%
airports_df = pd.read_csv('./airports.csv', encoding='utf-8')

# %%
cargo_transport_df = pd.read_csv('./cargo transportation.csv', encoding='utf-8', sep=';')

# %%
aircraft_df.head()
# Out:
#   Вид воздушного судна Тип (наименование) воздушного судна  \
# 0              самолет                            Птенец-2
# 1            дельталет                              Аватар
# 2              самолет                          С-2 Елочка
# 3            дельталет                               СОКОЛ
# 4              самолет                            Небесный
#
#   Опознавательные знаки Серийный № Идентификац. №  \
# 0              RA-0001A        NaN   ЕЭВС.03.1529
# 1              RA-0002A        NaN   ЕЭВС.03.1709
# 2              RA-0002G        NaN   ЕЭВС.02.0126
# 3              RA-0003A        NaN   ЕЭВС.03.1708
# 4              RA-0003G        NaN   ЕЭВС.02.0013
#
#   номер свидетельства о регистрации  \
# 0                              0001
# 1                              0002
# 2                              0224
# 3                              0003
# 4                              0225
#
#   дата действующего свидетельства о регистрации
# 0                                    2012-11-03
# 1                                    2012-03-16
# 2                                    2006-02-06
# 3                                    2012-03-16
# 4                                    2008-07-04

# %%
aircraft_df.isnull().any()
# Out:
# Вид воздушного судна                             False
# Тип (наименование) воздушного судна              False
# Опознавательные знаки                            False
# Серийный №                                        True
# Идентификац. №                                    True
# номер свидетельства о регистрации                False
# дата действующего свидетельства о регистрации    False
# dtype: bool

# %%
airlines_df.head()
# Out:
#                       Индекс  \
# 551               Абакан Эир
# 481     Авиа Менеджмент Груп
# 554  Авиакомпания «Лайт Эйр»
# 284       Авиакомпания СОКОЛ
# 442        Авиакон Цитотранс
#
#                                               Название  \
# 551  Общество с ограниченной ответственностью «АБАК...
# 481        Акционерное общество «Авиа Менеджмент Груп»
# 554  Закрытое акционерное общество Авиакомпания «Ла...
# 284  Закрытое акционерное общество  Авиакомпания «С...
# 442  Открытое акционерное общество  Авиакомпания «А...
#
#        Юридическое Название                                           Самолеты
# 551                  Абакан    Ил-76  (7), Ми-26  (3), Ми-8  (3), Ми-8МТВ  (5)
# 481         Иваново (Южный)                                Pilatus PC-12  (10)
# 554                     Уфа  BK-117  (1), Robinson R-44  (17), Ан-2  (7), R...
# 284  Новотитаровская-Азимут                               Ми-2  (1), Ми-8  (1)
# 442  Екатеринбург(Кольцово)                                         Ил-76  (5)

# %%
airlines_df.isnull().any()
# Out:
# Индекс                  False
# Название                False
# Юридическое Название     True
# Самолеты                 True
# dtype: bool

# %%
airports_df.head()
# Out:
#                            Наименование аэропорта РФ  \
# 0                             Архангельск (Талаги)
# 1     Нарьян-Мар  В 3 км восточнее г.Нарьян-Мар, НАО
# 2  Васьково  12 км юго-западнее г.Архангельск, Ар...
# 3  Котлас  3 км юго-восточнее г.Котлас, Архангель...
# 4  Лешуконское  1,3 км юго-западнее села Лешуконс...
#
#                                        Свидетельство  \
# 0  Сертификат МАК № 061А-М, 27.09.2013-03.08.2018...
# 1  Свидетельство о государственной регистрации и ...
# 2  Свидетельство о государственной регистрации и ...
# 3  Свидетельство о государственной регистрации и ...
# 4  Свидетельство о государственной регистрации и ...
#
#                                             Юрлицо Тип
# 0                       ОАО «Аэропорт Архангельск»   В
# 1      ОАО «Нарьян-Марский объединенный авиаотряд»   В
# 2  ОАО «2-ой Архангельский объединенный авиаотряд»   Г
# 3                                 ОАО «Аэросервис»   Г
# 4                     ОАО «Аэропорт Лешуконское»     Г

# %%
airports_df.isnull().any()
# Out:
# Наименование аэропорта РФ     True
# Свидетельство                False
# Юрлицо                       False
# Тип                          False
# dtype: bool

# %%
cargo_transport_df.head()
# Out:
#   Наименование аэропорта РФ  Год периода данных  Январь Февраль    Март  \
# 0                    Абакан                2018   63,39   60,98   69,46
# 1                     Айхал                2018     ***     ***     ***
# 2                     Алдан                2018     ***     ***     ***
# 3                   Амдерма                2018     ***     ***     ***
# 4                   Анадырь                2018  112,58  267,65  221,77
#
#    Апрель     Май   Июнь    Июль Август Сентябрь Октябрь Ноябрь Декабрь  \
# 0   88,62   83,81  64,99   49,64  70,26    87,35     NaN    NaN     NaN
# 1     ***     ***    ***     ***    ***      ***     NaN    NaN     NaN
# 2     ***     ***    ***     ***    ***      ***     NaN    NaN     NaN
# 3     ***     ***    ***     ***    ***      ***     NaN    NaN     NaN
# 4  331,37  160,45  89,77  109,29  95,99   103,77     NaN    NaN     NaN
#
#   Январь - Декабрь
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
cargo_transport_df.isnull().any()
# Out:
# Наименование аэропорта РФ    False
# Год периода данных           False
# Январь                       False
# Февраль                      False
# Март                         False
# Апрель                       False
# Май                          False
# Июнь                         False
# Июль                         False
# Август                       False
# Сентябрь                     False
# Октябрь                       True
# Ноябрь                        True
# Декабрь                       True
# Январь - Декабрь              True
# dtype: bool

# %% [markdown]
# ##  Список уникальных типов самолетов, зарегистрированных в России
#
# ![image.png](attachment:image.png)

# %%
unique_aircrafts_df = aircraft_df.loc[aircraft_df['Опознавательные знаки'].str.startswith('RA'), ['Вид воздушного судна', 'Тип (наименование) воздушного судна']]

# %%
unique_aircrafts_df = unique_aircrafts_df[unique_aircrafts_df['Вид воздушного судна'] == 'самолет']

# %%
unique_aircrafts_series = pd.Series(unique_aircrafts_df['Тип (наименование) воздушного судна'].unique())
unique_aircrafts_series
# Out:
# 0                   Птенец-2
# 1                 С-2 Елочка
# 2                   Небесный
# 3                    Светлый
# 4                       Сура
# 5                   EUROSTAR
# 6                Pioneer 330
# 7                   СП-30З О
# 8                     Саргон
# 9               Аэропракт-20
# 10                    Ястреб
# 11              Рейнджер МПВ
# 12               Икарус С42В
# 13               С22В Икарус
# 14            Авиатика-890СХ
# 15              С-2УТ Синтал
# 16            Х-32-912УТ Гор
# 17             Peregrrine SL
# 18               EuroStar SL
# 19              EuroStar SLW
# 20                    СП-34М
# 21                   Саванна
# 22               FK-9 Mark-3
# 23                     Z-602
# 24                    А-27МС
# 25                Дельфин-10
# 26           АС-5М Альбатрос
# 27                    Вимана
# 28            Аэропракт-22L2
# 29        Авиатика-МАИ-890СХ
#                 ...
# 1823                   Ан-74
# 1824            Ан-74ТК-100С
# 1825                  Ан-74Д
# 1826               Ан-74-200
# 1827                  Ил-18Е
# 1828                  Ил-18Д
# 1829                  Ил-18В
# 1830                 Ил-76ТД
# 1831              Ил-76ТД-90
# 1832                  Ил-76Т
# 1833            Ил-76ТД-90ВД
# 1834                 Ил-76МД
# 1835              Ан-124-100
# 1836                  Ан-124
# 1837                 Ту-154М
# 1838                 Ту-154Б
# 1839               Ту-154Б-1
# 1840               Ту-154Б-2
# 1841                   Ил-86
# 1842                  Ил-62М
# 1843                   Ил-76
# 1844                   Ил-62
# 1845                 RRJ-95B
# 1846            RRJ-95LR-100
# 1847                  Ил-114
# 1848               Ил-96-300
# 1849             Ил-96-300ПУ
# 1850         Ил-96-300ПУ(М1)
# 1851    Ил-96-400Т/IL96-400T
# 1852           Ил-96-400 ВПУ
# Length: 1853, dtype: object

# %% [markdown]
# ## Какой тип самолета имеет самую раннюю дату выдчи сертификата

# %%
early_type_df = aircraft_df.loc[aircraft_df['дата действующего свидетельства о регистрации'].index.min(), ['Тип (наименование) воздушного судна']]

# %%
early_type_df
# Out:
# Тип (наименование) воздушного судна    Птенец-2
# Name: 0, dtype: object

# %% [markdown]
# ## Построить запрос: Владелец Аэропорта, Аэропорт, Пассажиропоток суммарный за 2018, грузопоток суммарный за 2018

# %%
cargo_transport_2018_df = cargo_transport_df[cargo_transport_df['Год периода данных'] == 2018]
query_airports_df = pd.merge(airports_df, cargo_transport_2018_df)

# %%
query_airports_df
# Out:
#    Наименование аэропорта РФ  \
# 0                       Ухта
# 1                     Усинск
# 2                     Печора
# 3                     Братск
# 4                   Усть-Кут
# 5                       Мама
# 6                    Бодайбо
# 7                    Киренск
# 8                  Ербогачен
# 9                Нижнеудинск
# 10              Нижнеангарск
# 11                      Чара
# 12                     Айхал
# 13             Верхневилюйск
# 14               Депутатский
# 15                     Ленск
# 16                    Мирный
# 17                  Полярный
# 18             Среднеколымск
# 19                     Тикси
# 20                   Хандыга
# 21                    Якутск
# 22                    Абакан
# 23                    Диксон
# 24                   Озерная
#
#                                         Свидетельство  \
# 0   Свидетельство о государственной регистрации и ...
# 1   Свидетельство о государственной регистрации и ...
# 2   Свидетельство о государственной регистрации и ...
# 3    Сертификат МАК № 054 А-М  30.08.2010  18.09.2015
# 4   Свидетельство о государственной регистрации и ...
# 5   Свидетельство о государственной регистрации и ...
# 6   Свидетельство о государственной регистрации и ...
# 7   Свидетельство о государственной регистрации и ...
# 8   Свидетельство о государственной регистрации и ...
# 9   Свидетельство о государственной регистрации и ...
# 10  Свидетельство о государственной регистрации и ...
# 11  Свидетельство о государственной регистрации и ...
# 12  Сертификат Росавиации № АД 0001/13  16.07.2014...
# 13                 Сертификат Росавиации № АД 0002/13
# 14  Свидетельство о государственной регистрации и ...
# 15  Свидетельство о государственной регистрации и ...
# 16                    Сертификат Росавиации № АД 0009
# 17                  Сертификат Росавиации № АД 00013
# 18  Свидетельство о государственной регистрации и ...
# 19  Свидетельство о государственной регистрации и ...
# 20  Свидетельство о государственной регистрации и ...
# 21            Сертификат МАК № 036 А-М  -  27.02.2015
# 22    Сертификат МАК № 087 А-М 07.09.2011  07.09.2016
# 23  Свидетельство о государственной регистрации и ...
# 24  Сертификат Росавиации № 12/2  14.10.2014  14.1...
#
#                                                Юрлицо  Тип  \
# 0                              ОАО  «Комиавиатранс»      В
# 1                                ОАО  «Комиавиатранс»    В
# 2                              ОАО  «Комиавиатранс»      Г
# 3                                    ПАО «АэроБратск»    Б
# 4                             ОАО «Аэропорт Усть-Кут»    Г
# 5                              ООО «Мамский аэропорт»    Г
# 6        Бодайбинское авиапредприятие, ЗАО «Ленсиб»      Г
# 7                             ООО «Аэропорт «Киренск»    Г
# 8                             ООО «Аэропорт «Киренск»    Д
# 9                         ООО «Аэропорт «Нижнеудинск»    Е
# 10                          ОАО «Аэропорты Бурятии»      Д
# 11                                   ООО «Аэропорт»      Г
# 12  Мирнинское авиационное предприятие АК АЛРОСА" ...    Г
# 13                             ФКП Аэропорты Севера""    Г
# 14                             ФКП Аэропорты Севера""    Г
# 15  Мирнинское авиационное предприятие АК АЛРОСА" ...    Г
# 16  Мирнинское авиационное предприятие АК АЛРОСА" ...    В
# 17  Мирнинское авиационное предприятие АК АЛРОСА" ...    Б
# 18                             ФКП Аэропорты Севера""    Г
# 19  Аэродром совместного базирования. в оперативно...    Г
# 20                             ФКП Аэропорты Севера""    Г
# 21                              ОАО Аэропорт Якутск""    Б
# 22                              ОАО «Аэропорт Абакан»    Б
# 23                                   ГП КК «КрасАвиа»    Е
# 24                          ФКП  «Аэропорты Камчатки»  Д
#
#     Год периода данных  Январь Февраль    Март  Апрель     Май    Июнь  \
# 0                 2018     ***     ***     ***     ***     ***     ***
# 1                 2018     ***     ***     ***     ***     ***     ***
# 2                 2018     ***     ***     ***     ***     ***     ***
# 3                 2018     ***     ***     ***     ***     ***     ***
# 4                 2018     ***     ***     ***     ***     ***     ***
# 5                 2018     ***     ***     ***     ***     ***     ***
# 6                 2018     ***     ***     ***     ***     ***     ***
# 7                 2018     ***     ***     ***     ***     ***     ***
# 8                 2018     ***     ***     ***     ***     ***     ***
# 9                 2018     ***     ***     ***     ***     ***     ***
# 10                2018     ***     ***     ***     ***     ***     ***
# 11                2018     ***     ***     ***     ***     ***     ***
# 12                2018     ***     ***     ***     ***     ***     ***
# 13                2018     ***     ***     ***     ***     ***     ***
# 14                2018     ***     ***     ***     ***     ***     ***
# 15                2018   16,79   21,72   24,87   41,68   74,54   45,63
# 16                2018   559,1  532,09  688,65  785,74  929,85  657,97
# 17                2018   17,13   27,71   29,02   30,26   74,64    54,2
# 18                2018     ***     ***     ***     ***     ***     ***
# 19                2018   32,61   26,34   40,63   32,99   35,95   48,44
# 20                2018     ***     ***     ***     ***     ***     ***
# 21                2018  507,45  726,99  890,64  848,08   743,5  876,79
# 22                2018   63,39   60,98   69,46   88,62   83,81   64,99
# 23                2018     ***     ***     ***     ***     ***     ***
# 24                2018     ***     ***     ***     ***     ***     ***
#
#       Июль  Август Сентябрь Октябрь Ноябрь Декабрь Январь - Декабрь
# 0      ***     ***      ***     NaN    NaN     NaN              NaN
# 1      ***     ***      ***     NaN    NaN     NaN              NaN
# 2      ***     ***      ***     NaN    NaN     NaN              NaN
# 3      ***     ***      ***     NaN    NaN     NaN              NaN
# 4      ***     ***      ***     NaN    NaN     NaN              NaN
# 5      ***     ***      ***     NaN    NaN     NaN              NaN
# 6      ***     ***      ***     NaN    NaN     NaN              NaN
# 7      ***     ***      ***     NaN    NaN     NaN              NaN
# 8      ***     ***      ***     NaN    NaN     NaN              NaN
# 9      ***     ***      ***     NaN    NaN     NaN              NaN
# 10     ***     ***      ***     NaN    NaN     NaN              NaN
# 11     ***     ***      ***     NaN    NaN     NaN              NaN
# 12     ***     ***      ***     NaN    NaN     NaN              NaN
# 13     ***     ***      ***     NaN    NaN     NaN              NaN
# 14     ***     ***      ***     NaN    NaN     NaN              NaN
# 15   44,85   52,36    40,74     NaN    NaN     NaN              NaN
# 16  469,96  593,53   578,72     NaN    NaN     NaN              NaN
# 17   41,13   40,31    31,88     NaN    NaN     NaN              NaN
# 18     ***     ***      ***     NaN    NaN     NaN              NaN
# 19   38,67   34,14     29,2     NaN    NaN     NaN              NaN
# 20     ***     ***      ***     NaN    NaN     NaN              NaN
# 21  770,84  829,77    861,4     NaN    NaN     NaN              NaN
# 22   49,64   70,26    87,35     NaN    NaN     NaN              NaN
# 23     ***     ***      ***     NaN    NaN     NaN              NaN
# 24     ***     ***      ***     NaN    NaN     NaN              NaN
